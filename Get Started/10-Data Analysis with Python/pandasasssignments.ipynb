# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas

# %%
### Assignment 1: DataFrame Creation and Indexing

## 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.

import pandas as pd
import numpy as np

pandas_dataframe=pd.DataFrame(np.random.randint(1,101,size=(6,4)),columns=['A','B','C','D'])
print(pandas_dataframe)

pandas_dataframe.set_index('A',inplace=True)
print(pandas_dataframe)


## 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.

datas=pd.DataFrame(np.random.randint(1,101,size=(3,3)),columns=['A', 'B', 'C'],index=['X', 'Y', 'Z'])

print(datas)

df=datas.at['Y','B']
print(df)
# Out:
#     A   B    C   D
# 0  33  59   75  38
# 1  71  88   15  95
# 2  72  66  100  63
# 3  71  25   50  63
# 4  85  17   87  31
# 5  81  68    5  98
#      B    C   D
# A
# 33  59   75  38
# 71  88   15  95
# 72  66  100  63
# 71  25   50  63
# 85  17   87  31
# 81  68    5  98
#     A   B   C
# X  89   7  73
# Y  12  55  74
# Z  34  56  61
# 55

# %%
### Assignment 2: DataFrame Operations
## 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.

df= pd.DataFrame(np.random.randint(1,21,size=(5,3)),columns=['A','B','C'])
print(df)

df['D']=df['A']*df['B']
print(df)

## 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

new_df=pd.DataFrame(np.random.randint(3,50,size=(4,3)),columns=['Q','W','E'])
print(new_df)

## (sum across columns for each row)
print("row_num: ")
row_sum=new_df.sum(axis=1)
print(row_sum)

print("column_sum: ")
column_sum=new_df.sum(axis=0)
print(column_sum)
# Out:
#     A   B   C
# 0  15   9  17
# 1   6  11   1
# 2  14  13   2
# 3  15  18  14
# 4   4  11   4
#     A   B   C    D
# 0  15   9  17  135
# 1   6  11   1   66
# 2  14  13   2  182
# 3  15  18  14  270
# 4   4  11   4   44
#     Q   W   E
# 0  42  35  46
# 1  22  46  17
# 2  40  36  18
# 3  32   6  21
# row_num:
# 0    123
# 1     85
# 2     94
# 3     59
# dtype: int64
# column_sum:
# Q    136
# W    123
# E    102
# dtype: int64

# %%
### Assignment 3: Data Cleaning

## 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.

df=pd.DataFrame(np.random.randint(1,50,size=(5,3)),columns=["A","B","C"])
print(df)

## NAN values
df.iloc[0,1]=np.nan
df.iloc[1,2]=np.nan
df.iloc[2,1]=np.nan

print("\nwith NAN:")
print(df)

df.fillna(df.mean(),inplace=True)
print(df)

# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.

print("\nDF2: ")
df2=pd.DataFrame(np.random.randint(1,100,size=(6,4)))
print(df2)

df2.iloc[0,0]=np.nan
df2.iloc[1,1]=np.nan
df2.iloc[2,2]=np.nan
# print("\niloc:\n")
print(df2)

df2.dropna(inplace=True)
print("\nDrop rows with NAN: ")
print(df2)
# Out:
#     A   B   C
# 0  19  34  39
# 1  49  32  36
# 2  21  35  10
# 3  14  46  28
# 4   1  13  31
#
# with NAN:
#     A     B     C
# 0  19   NaN  39.0
# 1  49  32.0   NaN
# 2  21   NaN  10.0
# 3  14  46.0  28.0
# 4   1  13.0  31.0
#     A          B     C
# 0  19  30.333333  39.0
# 1  49  32.000000  27.0
# 2  21  30.333333  10.0
# 3  14  46.000000  28.0
# 4   1  13.000000  31.0
#
# DF2:
#     0   1   2   3
# 0   7  15  80  29
# 1  23  10   1  39
# 2  18  63  43  78
# 3  13  46  94  37
# 4   5   8  42   9
# 5  27  25  81  63
#       0     1     2   3
# 0   NaN  15.0  80.0  29
# 1  23.0   NaN   1.0  39
# 2  18.0  63.0   NaN  78
# 3  13.0  46.0  94.0  37
# 4   5.0   8.0  42.0   9
# 5  27.0  25.0  81.0  63
#
# Drop rows with NAN:
#       0     1     2   3
# 3  13.0  46.0  94.0  37
# 4   5.0   8.0  42.0   9
# 5  27.0  25.0  81.0  63

# %%
### Assignment 4: Data Aggregation

## 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.

df=pd.DataFrame({'Category':np.random.choice(['A','B','C'],size=8),'Value':np.random.randint(1,11,size=8)})
print(df)

group_dataframe= df.groupby('Category')['Value'].agg(['sum','mean'])
print(group_dataframe)

## 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.

df=pd.DataFrame({'Product':np.random.choice(['Product1','Product2','Product3'],size=9),'Category':np.random.choice(['A','B','C'],size=9),'Sales':np.random.randint(1,11,9)})
print("DataFrame2: \n",df)

group_category2=df.groupby('Category')['Sales'].sum()
print(group_category2)
# Out:
#   Category  Value
# 0        A      8
# 1        B      7
# 2        B      7
# 3        C      4
# 4        B      9
# 5        B      5
# 6        B      5
# 7        C      8
#           sum  mean
# Category
# A           8   8.0
# B          33   6.6
# C          12   6.0
# DataFrame2:
#      Product Category  Sales
# 0  Product3        C     10
# 1  Product1        C     10
# 2  Product3        C      9
# 3  Product1        B     10
# 4  Product1        C      2
# 5  Product2        B      9
# 6  Product1        A      5
# 7  Product3        B     10
# 8  Product1        B      2
# Category
# A     5
# B    31
# C    31
# Name: Sales, dtype: int32

# %%
### Assignment 5: Merging DataFrames

## 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.

df1=pd.DataFrame(
    {
        'Key':['A','B','C','D'],
        'Value1':np.random.randint(1,21,size=4)
    }
)

print("DF1: \n",df1)

df2=pd.DataFrame(
    {
        'Key':['A','B','C','G'],
        'Value2':np.random.randint(1,21,size=4)
    }
)
print("DF2: \n",df2)

merged=pd.merge(df1,df2,on='Key',how='inner')

print('merged\n',merged)

## 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.

df1=pd.DataFrame({
    'A':np.random.randint(1,11,size=4),
    'B':np.random.randint(11,21,size=4)
}) 

print("DF1: \n",df1)

df2=pd.DataFrame({
    'C':np.random.randint(21,31,size=4),
    'D':np.random.randint(31,41,size=4)
})
print("DF2: \n",df2)

concat_row=pd.concat([df1,df2],axis=0)
print("Concat row: \n",concat_row)

concat_col=pd.concat([df1,df2],axis=1)
print("Concat Column: \n",concat_col)
# Out:
# DF1:
#    Key  Value1
# 0   A      14
# 1   B      15
# 2   C      11
# 3   D       5
# DF2:
#    Key  Value2
# 0   A      15
# 1   B      19
# 2   C       7
# 3   G      20
# merged
#    Key  Value1  Value2
# 0   A      14      15
# 1   B      15      19
# 2   C      11       7
# DF1:
#     A   B
# 0  6  14
# 1  1  13
# 2  2  15
# 3  7  20
# DF2:
#      C   D
# 0  29  31
# 1  25  36
# 2  29  38
# 3  30  39
# Concat row:
#       A     B     C     D
# 0  6.0  14.0   NaN   NaN
# 1  1.0  13.0   NaN   NaN
# 2  2.0  15.0   NaN   NaN
# 3  7.0  20.0   NaN   NaN
# 0  NaN   NaN  29.0  31.0
# 1  NaN   NaN  25.0  36.0
# 2  NaN   NaN  29.0  38.0
# 3  NaN   NaN  30.0  39.0
# Concat Column:
#     A   B   C   D
# 0  6  14  29  31
# 1  1  13  25  36
# 2  2  15  29  38
# 3  7  20  30  39

# %%
### Assignment 6: Time Series Analysis

## 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.

date_time_index=pd.date_range(start='2022-01-01',end='2022-12-31',freq='D')
print(date_time_index)
df=pd.DataFrame(date_time_index,columns=['date'])
# print(df)
df['data']=np.random.randint(1,100,size=len(date_time_index))  #size=(len(date_rng)) ensures one value per day.
df.set_index('date',inplace=True)
print(df)

##ReSample the Dataframe
monthly_mean=df.resample('ME').mean()  #df.resample('ME')-->“Group the data by calendar month (month end frequency = ME)”. #We use resample whenever we want to summarize, aggregate, or restructure time-series data into a different frequency (daily → weekly, weekly → monthly, etc.).

print("monthly_mean",monthly_mean)

## 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

date_time_index2=pd.date_range(start='2021-01-01',end='2021-12-31',freq='D')
df2=pd.DataFrame(date_time_index2,columns=['Date'])
# print('df2\n',df2)
df2['data']=np.random.randint(0,100,size=(len(date_time_index2)))
df2.set_index('Date',inplace=True)
# print(df2)

## rolling mean with a window of 7 days.
rolling_mean=df.rolling(window=7).mean()  # rolling(window=7).mean() is calculating a 7-day moving average of your data column.
print("rolling_mean \n",rolling_mean)
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')
#             data
# date
# 2022-01-01    20
# 2022-01-02    39
# 2022-01-03    71
# 2022-01-04    44
# 2022-01-05    26
# ...          ...
# 2022-12-27     7
# 2022-12-28    86
# 2022-12-29    74
# 2022-12-30    68
# 2022-12-31    40
#
# [365 rows x 1 columns]
# monthly_mean                  data
# date
# 2022-01-31  51.838710
# 2022-02-28  50.035714
# 2022-03-31  47.419355
# 2022-04-30  50.166667
# 2022-05-31  49.677419
# 2022-06-30  52.466667
# 2022-07-31  51.225806
# 2022-08-31  42.451613
# 2022-09-30  42.833333
# 2022-10-31  47.645161
# 2022-11-30  56.800000
# 2022-12-31  48.580645
# rolling_mean
#                   data
# date
# 2022-01-01        NaN
# 2022-01-02        NaN
# 2022-01-03        NaN
# 2022-01-04        NaN
# 2022-01-05        NaN
# ...               ...
# 2022-12-27  43.428571
# 2022-12-28  46.142857
# 2022-12-29  43.142857
# 2022-12-30  47.571429
# 2022-12-31  46.000000
#
# [365 rows x 1 columns]

# %%
### Assignment 7: MultiIndex DataFrame

## 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.

arrays=[['A','A','B','B'],['one','two','one','two']]
index=pd.MultiIndex.from_arrays(arrays,names=('Category','SubCategory'))
df=pd.DataFrame(np.random.randint(1,50,size=(4,3)),index=index,columns=["Value1","Value2","Value3"])

print(df)

# indexing
print("Indexing-1: \n")
print(df.loc['A'],"\n")
print("Indexing-2: \n")
print(df.loc['B','two'])


## 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.

arrays2=[['A','A','B','B'],['one','two','one','two']]
index=pd.MultiIndex.from_arrays(arrays2,names=('Category','SubCategory'))
df=pd.DataFrame(np.random.randint(1,60,size=(4,3)),index=index,columns=["Value1","Value2","Value3"])
# print("df: \n",df)

sum_values=df.groupby(['Category','SubCategory']).sum()
print("sum: \n",sum_values)
# Out:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              21       4      43
#          two              25      23      47
# B        one              22      13      39
#          two               5       9      39
# Indexing-1:
#
#              Value1  Value2  Value3
# SubCategory
# one              21       4      43
# two              25      23      47
#
# Indexing-2:
#
# Value1     5
# Value2     9
# Value3    39
# Name: (B, two), dtype: int32
# sum:
#                        Value1  Value2  Value3
# Category SubCategory
# A        one               5      17      55
#          two              13      40       2
# B        one               6      43      47
#          two              55      57      39

# %%
### Assignment 8: Pivot Tables

## 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.  
date_rng=pd.date_range(start="2025-01-02",end="2025-05-08",freq="D")
df=pd.DataFrame({
    "Date": np.random.choice(date_rng,size=20),
    "Category": np.random.choice((['A','B','C']),size=20),
    "Value":np.random.randint(1,100,size=20)
    })
# print("Original DataFrame: \n")
# print(df)

pivot_table=df.pivot_table(columns="Category",values="Value",index="Date" ,aggfunc="sum")
print("Pivot Table: \n")
print(pivot_table)

## 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
# Out:
# Pivot Table:
#
# Category       A     B     C
# Date
# 2025-01-05   NaN   NaN  84.0
# 2025-01-07  12.0   NaN   NaN
# 2025-01-09   NaN  34.0   NaN
# 2025-01-15   NaN  88.0   NaN
# 2025-01-19   NaN  74.0   NaN
# 2025-02-05   NaN   NaN  45.0
# 2025-02-06   NaN  22.0   NaN
# 2025-02-11  50.0   NaN   NaN
# 2025-02-14  57.0   NaN   NaN
# 2025-02-18  40.0   NaN   NaN
# 2025-02-20   NaN  43.0   NaN
# 2025-02-21   NaN  68.0   NaN
# 2025-03-01  25.0   NaN   NaN
# 2025-03-04   NaN   NaN  77.0
# 2025-03-21   NaN  41.0   NaN
# 2025-03-23   NaN   NaN  84.0
# 2025-03-30   NaN   NaN   4.0
# 2025-04-11   NaN  20.0   NaN
# 2025-04-21   NaN   NaN  64.0

# %%
### Assignment 9: Applying Functions

## 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
## 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.

# %%
### Assignment 10: Working with Text Data

## 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
## 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.
